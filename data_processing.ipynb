# %%
import pandas as pd

# %%
# checking raw dataset
data_path = "data.csv"
df = pd.read_csv(data_path, on_bad_lines='skip').copy() #copy to avoid data changing in the original dataset
print(df.columns)
df.sample(n=10)
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 1968     1969                  2   Not Graduate             No        1700000
# 927       928                  3       Graduate            Yes        7200000
# 4223     4224                  0   Not Graduate             No        2700000
# 675       676                  4   Not Graduate            Yes        4600000
# 2493     2494                  3       Graduate             No        2000000
# 3602     3603                  0   Not Graduate            Yes        1900000
# 1870     1871                  3   Not Graduate            Yes        8300000
# 2312     2313                  2       Graduate             No        2200000
# 718       719                  4       Graduate             No         700000
# 785       786                  2   Not Graduate            Yes         600000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 1968       5300000          20           761                    2500000
# 927       20400000          10           558                          0
# 4223       8400000          14           610                     900000
# 675        9500000          20           613                    5200000
# 2493       4200000           6           831                    1300000
# 3602       6400000          20           704                     900000
# 1870      20900000           4           615                    4400000
# 2312       7000000           6           777                    6100000
# 718        2600000          14           736                    2100000
# 785        2100000          18           572                     400000
#
#        commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 1968                    500000               3700000            1200000
# 927                   13200000              27200000           10600000
# 4223                   1900000               6100000            2800000
# 675                    5900000              13700000            3000000
# 2493                   1700000               6900000            1200000
# 3602                   3400000               5300000            1900000
# 1870                    200000              19000000            9600000
# 2312                    400000               4400000            3300000
# 718                     600000               1900000             400000
# 785                     500000               1400000             300000
#
#       loan_status
# 1968     Approved
# 927      Approved
# 4223     Approved
# 675      Approved
# 2493     Approved
# 3602     Approved
# 1870     Approved
# 2312     Approved
# 718      Approved
# 785      Approved

# %%
# since column names include white spaces, they have to be trimmed.

df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status'],
#       dtype='object')

# %%
# one hot encoding for finite enumeration features
df = pd.get_dummies(df, columns=['education', 'self_employed',])
df.sample(n=10)
# Out:
#       loan_id  no_of_dependents  income_annum  loan_amount  loan_term  \
# 1410     1411                 2       9500000     25400000         16
# 647       648                 0       3000000      9600000         12
# 1938     1939                 4       1200000      4800000          2
# 3520     3521                 3       6900000     22700000          4
# 1477     1478                 4       1200000      3300000         12
# 2503     2504                 2       5500000     19600000         16
# 1022     1023                 5       8800000     18800000         14
# 2303     2304                 2       8400000     32600000         10
# 765       766                 0       7900000     31500000         14
# 1901     1902                 0       4000000     12500000         18
#
#       cibil_score  residential_assets_value  commercial_assets_value  \
# 1410          451                  19000000                  2900000
# 647           620                   7900000                        0
# 1938          752                   2800000                   900000
# 3520          650                    900000                 13400000
# 1477          876                    400000                   100000
# 2503          328                   2400000                  4800000
# 1022          836                  17300000                 10100000
# 2303          384                  13900000                  1600000
# 765           849                  19400000                 10300000
# 1901          868                  11000000                   800000
#
#       luxury_assets_value  bank_asset_value loan_status  education_ Graduate  \
# 1410             33800000          11400000    Rejected                False
# 647               8600000           3600000    Approved                 True
# 1938              3000000            600000    Approved                 True
# 3520             15500000           6400000    Approved                False
# 1477              3800000           1000000    Approved                False
# 2503             10900000           3700000    Rejected                False
# 1022             32700000           5400000    Approved                 True
# 2303             21600000           7000000    Rejected                 True
# 765              26600000          10600000    Approved                False
# 1901             14400000           2300000    Approved                False
#
#       education_ Not Graduate  self_employed_ No  self_employed_ Yes
# 1410                     True               True               False
# 647                     False               True               False
# 1938                    False              False                True
# 3520                     True               True               False
# 1477                     True               True               False
# 2503                     True               True               False
# 1022                    False               True               False
# 2303                    False              False                True
# 765                      True               True               False
# 1901                     True               True               False

# %%
# label encoding target value (loan_status)
from sklearn.calibration import LabelEncoder


label_encoder = LabelEncoder()
df['loan_status'] = label_encoder.fit_transform(df['loan_status'])

df.sample(n=10)
# Out:
#       loan_id  no_of_dependents  income_annum  loan_amount  loan_term  \
# 3895     3896                 0       1800000      5200000         16
# 4035     4036                 1       7300000     19200000         14
# 257       258                 2       8000000     20000000          2
# 3310     3311                 5       8500000     23400000         16
# 2937     2938                 1       2200000      5400000         16
# 2457     2458                 1       2100000      4300000         20
# 87         88                 1       8700000     28300000          8
# 3457     3458                 4       8600000     20900000         10
# 1618     1619                 1       5300000     14100000         14
# 2582     2583                 0       6800000     21700000         20
#
#       cibil_score  residential_assets_value  commercial_assets_value  \
# 3895          317                   4900000                  1500000
# 4035          599                  18400000                  5400000
# 257           502                   4100000                  2200000
# 3310          604                  25100000                 16500000
# 2937          641                   5900000                        0
# 2457          896                    100000                  2300000
# 87            402                  20400000                 13600000
# 3457          867                  24300000                  7200000
# 1618          510                  13300000                 10400000
# 2582          730                  17500000                  1300000
#
#       luxury_assets_value  bank_asset_value  loan_status  education_ Graduate  \
# 3895              4000000           1300000            1                 True
# 4035             15900000           3700000            0                False
# 257              31600000           9900000            1                False
# 3310             24500000           4800000            0                False
# 2937              4800000           1200000            0                False
# 2457              7500000           2300000            0                 True
# 87               27900000          10200000            1                False
# 3457             23700000           9900000            0                False
# 1618             18900000           7800000            1                False
# 2582             18600000           3600000            0                 True
#
#       education_ Not Graduate  self_employed_ No  self_employed_ Yes
# 3895                    False              False                True
# 4035                     True               True               False
# 257                      True               True               False
# 3310                     True               True               False
# 2937                     True              False                True
# 2457                    False              False                True
# 87                       True              False                True
# 3457                     True               True               False
# 1618                     True              False                True
# 2582                    False               True               False

# %%
# scaling (standardization) numeric features
from sklearn.preprocessing import StandardScaler

standard_scaler = StandardScaler()


scaled_data = standard_scaler.fit_transform(df)

new_df = pd.DataFrame(scaled_data, columns=df.columns)

#moving the target column to last index for better visualization
new_df = new_df.drop(columns=['loan_status'])
new_df['loan_status'] = df['loan_status']
df = new_df.copy()
df.sample(n=10)
# Out:
#        loan_id  no_of_dependents  income_annum  loan_amount  loan_term  \
# 3253  0.908018          0.885344     -1.695744    -1.574096  -1.208798
# 2907  0.627255          1.475067      0.940982     0.571375   0.192617
# 2448  0.254797          1.475067      0.370879    -0.081113   0.893324
# 697  -1.166061         -1.473548      0.335248     0.969504  -1.208798
# 307  -1.482528          0.295621     -1.303798    -1.220203  -0.508091
# 1606 -0.428448          0.295621     -1.481955    -1.330795  -0.157737
# 2592  0.371646         -0.294102     -0.626801    -0.379710   0.542970
# 2794  0.535560          0.295621      0.263985     0.272779  -0.858444
# 2568  0.352172          0.295621     -0.234855     0.129010   1.594031
# 3590  1.181479          0.295621     -0.377381    -0.390769  -0.858444
#
#       cibil_score  residential_assets_value  commercial_assets_value  \
# 3253     1.142995                 -1.102992                -1.042088
# 2907     1.195196                  2.126349                 1.897445
# 2448    -1.159653                  0.265634                -0.495199
# 697     -1.194454                 -0.118812                 0.188414
# 307     -0.840647                 -0.687791                -0.814218
# 1606    -1.339457                 -0.933836                -1.110450
# 2592    -0.933449                 -0.534013                 0.302349
# 2794     0.696385                 -0.395612                -0.176180
# 2568    -0.225834                 -0.303345                 0.689729
# 3590    -0.353436                 -0.241834                -0.540773
#
#       luxury_assets_value  bank_asset_value  education_ Graduate  \
# 3253            -1.595826         -1.408298             0.995559
# 2907             0.414569          1.422642            -1.004461
# 2448             0.952872          0.191798             0.995559
# 697              0.744142         -0.146683             0.995559
# 307             -1.343153         -0.885189            -1.004461
# 1606            -1.474983         -1.377527             0.995559
# 2592            -0.749922         -1.008274            -1.004461
# 2794             0.403583          0.499509             0.995559
# 2568            -0.343449         -0.300539            -1.004461
# 3590            -0.332463         -0.085141            -1.004461
#
#       education_ Not Graduate  self_employed_ No  self_employed_ Yes  \
# 3253                -0.995559          -0.992765            0.992765
# 2907                 1.004461           1.007288           -1.007288
# 2448                -0.995559          -0.992765            0.992765
# 697                 -0.995559          -0.992765            0.992765
# 307                  1.004461           1.007288           -1.007288
# 1606                -0.995559           1.007288           -1.007288
# 2592                 1.004461           1.007288           -1.007288
# 2794                -0.995559          -0.992765            0.992765
# 2568                 1.004461          -0.992765            0.992765
# 3590                 1.004461          -0.992765            0.992765
#
#       loan_status
# 3253            0
# 2907            0
# 2448            1
# 697             0
# 307             1
# 1606            1
# 2592            1
# 2794            0
# 2568            0
# 3590            1

# %%
# save the cleaned data into new csv file
df.to_csv("processed_data.csv",index=False)
